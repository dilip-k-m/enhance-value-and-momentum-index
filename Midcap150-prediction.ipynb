# %% [markdown]
# # Instllation and Setup

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from statsmodels.tsa.arima.model import ARIMA
import pickle

# %% [markdown]
# # Data Preprocessing and Visualization

# %%
# Collect historical data
# nifty_data = yf.download('^NSEI', start='2022-05-10', end='2024-05-10')
nasdaq_data = yf.download('^IXIC', start='2021-05-10', end='2024-05-10')
gold_data = yf.download('GC=F', start='2021-05-10', end='2024-05-10')
oil_data = yf.download('CL=F', start='2021-05-10', end='2024-05-10')

mid150_file = 'data/NIFTY_MIDCAP_150_Historical_PR_01012006to13052024.csv'
nifty_data = pd.read_csv(mid150_file)
nifty_data['Date'] = pd.to_datetime(nifty_data['Date'], format='%d %b %Y')
nifty_data.set_index('Date', inplace=True)
nifty_data = nifty_data[~nifty_data.index.duplicated()]
# nifty_data.rename(columns={'Close': 'nifty_close'}, inplace=True)

mid150_pe_file = 'data/NIFTY_MIDCAP_150_Historical_PE_PB_DIV_Data_01012006to13052024.csv'
pe = pd.read_csv(mid150_pe_file)
pe.rename(columns={'P/E': 'PE'}, inplace=True)
pe['Date'] = pd.to_datetime(pe['Date'], format='%d %b %Y')
pe.set_index('Date', inplace=True)
nifty_pe_data = pe

print(f'nifty_data  = {len(nifty_data)}')
print(f'nasdaq_data  = {len(nasdaq_data)}')
print(f'gold_data  = {len(gold_data)}')
print(f'oil_data  = {len(oil_data)}')
print(f'nifty_pe_data  = {len(nifty_pe_data)}')


# Merge dataframes on date index
merged_data = pd.concat([nifty_data['Close'], nasdaq_data['Close'], gold_data['Close'], oil_data['Close'], nifty_pe_data['PE']], axis=1).dropna()
merged_data.columns = ['nifty_close', 'nasdaq_close', 'gold_close', 'oil_close', 'nifty_pe']

print(f'merged_data  = {len(merged_data)}')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# nifty_data  = 4549
# nasdaq_data  = 756
# gold_data  = 757
# oil_data  = 757
# nifty_pe_data  = 2008
# merged_data  = 718

# %%
merged_data['nifty_close'].corr(merged_data['nasdaq_close'])
# Out:
# 0.47343079158633106

# %%
merged_data['nifty_close'].corr(merged_data['gold_close'])
# Out:
# 0.7326473426239495

# %%
merged_data['nifty_close'].corr(merged_data['oil_close'])
# Out:
# -0.18985606317120082

# %%
plt.figure(figsize=(10, 6))
plt.plot(nifty_data.index, nifty_data['Close'], label='Mid cap 150 Close Price')
plt.title('Mid cap 150 Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.figure(figsize=(10, 6))
plt.plot(nasdaq_data.index, nasdaq_data['Close'], label='Nasdaq Close Price')
plt.title('Nasdaq Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.figure(figsize=(10, 6))
plt.plot(gold_data.index, gold_data['Close'], label='Gold Close Price')
plt.title('Gold Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.figure(figsize=(10, 6))
plt.plot(oil_data.index, oil_data['Close'], label='Oil Close Price')
plt.title('Oil Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.figure(figsize=(10, 6))
plt.plot(nifty_pe_data.index, nifty_pe_data['PE'], label='PE')
plt.title('PE History')
plt.xlabel('Date')
plt.ylabel('PE')

plt.show()

# %%
merged_data.dropna(inplace=True)
merged_data.head()
# Out:
#             nifty_close  nasdaq_close   gold_close  oil_close nifty_pe
# Date
# 2021-05-10      9308.20  13401.860352  1837.500000  64.919998    39.81
# 2021-05-11      9384.05  13389.429688  1835.900024  65.279999    40.17
# 2021-05-12      9323.95  13031.679688  1822.599976  66.080002    39.86
# 2021-05-14      9188.35  13429.980469  1837.900024  65.370003    39.28
# 2021-05-17      9340.60  13379.049805  1867.500000  66.269997    39.17

# %% [markdown]
# # Build LSTM

# %%
# Check if there are any valid data points remaining
if merged_data.shape[0] == 0:
    print("Error: No valid data points remaining after dropping NaN values.")
else:
    # Normalize the features
    scaler = MinMaxScaler()
    scaled_features = scaler.fit_transform(merged_data)

    # Separate the features and target
    nifty_close = scaled_features[:, 0].reshape(-1, 1)
    features = scaled_features

    # Define and train LSTM model
    def create_lstm_model():
        model = Sequential()
        model.add(Input(shape=(60, 1)))
        model.add(LSTM(units=60,activation='relu',return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(units=60,activation='tanh',return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(units=120,activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(units=1))
        model.compile(optimizer='adam',loss='mean_squared_error')
        return model

    lstm_model = create_lstm_model()

# %%
lstm_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 60, 60)              │          14,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 60, 60)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 60, 60)              │          29,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 60, 60)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_8 (LSTM)                        │ (None, 120)                 │          86,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 130,921 (511.41 KB)
#  Trainable params: 130,921 (511.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model

# %%
lstm_model.fit(features.reshape(features.shape[0], features.shape[1], 1), nifty_close, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 16s 49ms/step - loss: 0.1476
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0421
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0197
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0136
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0123
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0121
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0120
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0113
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0097
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0081
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0090
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0065
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0060
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0047
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0043
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0040
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0034
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0029
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0025
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0030
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0022
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0028
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0021
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0022
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0020
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.0021
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0021
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0020
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0023
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0019
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0020
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0014
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0017
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0015
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0017
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0015
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0014
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0017
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012

# %% [markdown]
# # Making Predictions

# %%
    
    # Predict future 90 days using LSTM
    last_2_years_data = scaled_features[-252*2:]
    future_dates = pd.date_range(start='2024-05-11', periods=90)

    lstm_predictions = []
    current_features = last_2_years_data[-1].reshape(1, features.shape[1], 1)
    for _ in range(90):
        lstm_pred = lstm_model.predict(current_features)
        lstm_predictions.append(lstm_pred[0][0])
        current_features = np.roll(current_features, -1)
        current_features[-1][-1] = lstm_pred
        
    # Inverse transform predictions to get actual price values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaler.fit(nifty_data['Close'].values.reshape(-1, 1))  # Fit the scaler on the original closing prices
    actual_predictions = scaler.inverse_transform(np.array(lstm_predictions).reshape(-1, 1)).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %% [markdown]
# # Prediction Visualization

# %%
    plt.figure(figsize=(10, 6))
    plt.plot(nifty_data.index, nifty_data['Close'], label='Mid cap 150 Close Price')
    plt.plot(future_dates, actual_predictions, label='LSTM Predictions')
    plt.legend()
    plt.title('Mid cap 150 Close Price History with Predictions')
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.show()

# %% [markdown]
# # Prediction and Visualization using ARIMA

# %%
merged_data.index = pd.date_range(start=merged_data.index[0], periods=len(merged_data), freq='B')

# Fit an ARIMA model on Nifty 50 close prices
arima_model = ARIMA(merged_data['nifty_close'], order=(5, 1, 0))  # Example ARIMA order (p, d, q)
arima_model_fit = arima_model.fit()

# Generate predictions
forecast_steps = 90  # Number of future steps to forecast
forecast = arima_model_fit.forecast(steps=forecast_steps)

# Plot actual data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(merged_data.index, merged_data['nifty_close'], label='Actual Mid cap 150 Close Price')
plt.plot(pd.date_range(start=merged_data.index[-1], periods=forecast_steps+1, freq='B')[1:], forecast, label='ARIMA Forecasted Mid cap 150 Close Price')
plt.xlabel('Date')
plt.ylabel('Mid cap 150 Close Price')
plt.title('ARIMA Forecast for Mid cap 150 Close Price')
plt.legend()
plt.show()
